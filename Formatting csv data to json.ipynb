# %%
import pandas as pd

# %%
# Read the csv file and make it the dataframe

df = pd.read_csv("Percentile after tax.csv")

# %%
df.head(5)
# Out:
#    Percentile point for total income after tax     2000     2001     2002  \
# 0                                            1   4,570    4,600    4,760
# 1                                            2   4,800    4,800    5,000
# 2                                            3   5,010    4,990    5,250
# 3                                            4   5,260    5,200    5,490
# 4                                            5   5,500    5,410    5,730
#
#       2003     2004     2005     2006     2007     2008  ...     2012  \
# 0   4,840    4,800    4,950    5,170    5,370    5,570   ...   7,690
# 1   5,070    5,020    5,200    5,450    5,660    5,860   ...   7,910
# 2   5,330    5,260    5,450    5,710    5,930    6,150   ...   8,140
# 3   5,570    5,500    5,700    5,960    6,190    6,430   ...   8,360
# 4   5,830    5,730    5,940    6,210    6,450    6,710   ...   8,600
#
#       2013      2014      2015      2016      2017      2018      2019  \
# ...

# %%
import json

# Exporting the dataframe as a json file

exported_values = list(df.T.to_dict().values())

open("Percentile after tax.json","w").write(json.dumps(exported_values))

# %%
# Out:
# 46532
